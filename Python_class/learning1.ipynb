# %% [markdown]
# 생성자의 첫 번째 매개변수는 반드시 self 여야 한다.

# %%
class TV:
    def __init__(self, size):
        self.size = size

# %% [markdown]
# this가 아닌 self를 써야한다.

# %%
class Car:
    def __init__(self, color):
        self.color = color

# %% [markdown]
# 빈 부분 완성

# %%
class TV:

    cnt_products = 0

    def __init__(self, size):
        self.size = size
        TV.cnt_products += 1

mine = TV(60)

print(TV.cnt_products)
# Out:
# 1
