# %%
print("안녕하세요\n파이썬입니다.")
print("이름\t나이")
print("홍길동\t20")
print("백슬래시 출력: \\")
print("작은따옴표 출력: \'")
print("큰따옴표 출력: \"")
# Out:
# 안녕하세요
# 파이썬입니다.
# 이름	나이
# 홍길동	20
# 백슬래시 출력: \
# 작은따옴표 출력: '
# 큰따옴표 출력: "

# %%
print(r"안녕하세요\n파이썬입니다.")
print(r"C:\Python\new_folder")
# Out:
# 안녕하세요\n파이썬입니다.
# C:\Python\new_folder

# %%
a = "Hello"
b = "Python"

print(a + b)
print(a + " " + b)
# Out:
# HelloPython
# Hello Python

# %%
word = "Hi"
print(word * 3)
print("*" * 10)
# Out:
# HiHiHi
# **********

# %%
pi = 3.14159265

print(f"{pi}")
print(f"{pi:.2f}")
print(f"{pi:.3f}")
# Out:
# 3.14159265
# 3.14
# 3.142

# %%
text = "AB"
number = 1234

print(f"|{text:10}|")
print(f"|{number:10}|")
print(f"|{text:>10}|")
print(f"|{number:<10}|")
print(f"|{number:0>10}|")
# Out:
# |AB        |
# |      1234|
# |        AB|
# |1234      |
# |0000001234|

# %%
s = "Python"

print(s[0])    # 첫 글자
print(s[1])    # 두 번째 글자
print(s[-1])   # 마지막 글자
print(s[-2])   # 뒤에서 두 번째 글자
# Out:
# P
# y
# n
# o

# %%
s = "Python"

print(s[0:2])    # Py
print(s[2:6])    # thon
print(s[:3])     # Pyt
print(s[3:])     # hon
print(s[::2])    # Pto
print(s[::-1])   # nohtyP
# Out:
# Py
# thon
# Pyt
# hon
# Pto
# nohtyP

# %%
s = "Python"

for ch in s:
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n

# %%
s = "Python"
print(len(s))
# Out:
# 6

# %%
data = "apple banana orange"
result = data.split()

print(result)
# Out:
# ['apple', 'banana', 'orange']

# %%
date = "2026-04-06"
result = date.split("-")

print(result)
# Out:
# ['2026', '04', '06']

# %%
words = ["Python", "is", "easy"]

print(" ".join(words))
print("-".join(words))
# Out:
# Python is easy
# Python-is-easy

# %%
s = "   Python Programming   "

print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
# Python Programming
# Python Programming
#    Python Programming

# %%
s = "apple banana apple"

print(s.count("apple"))
print(s.count("a"))
# Out:
# 2
# 5

# %%
s1 = "Python"
s2 = "12345"
s3 = "Python123"
s4 = "Python!"

print(s1.isalpha())
print(s2.isdigit())
print(s3.isalnum())
print(s4.isalnum())
# Out:
# True
# True
# True
# False

# %%
num1 = "100"
num2 = "3.14"

print(int(num1) + 50)
print(float(num2) + 1.0)

a = 123
b = 3.14

print(str(a) + "점")
print(str(b) + "입니다")
# Out:
# 150
# 4.140000000000001
# 123점
# 3.14입니다

# %%
s1 = "Python"
s2 = "12345"
s3 = "Python123"
s4 = "Python!"

print(s1.isalpha())
print(s2.isdigit())
print(s3.isalnum())
print(s4.isalnum())
# Out:
# True
# True
# True
# False

# %%
s = "Python Programming"

print(s.upper())
print(s.lower())
print(s.swapcase())
print(s.title())
# Out:
# PYTHON PROGRAMMING
# python programming
# pYTHON pROGRAMMING
# Python Programming
